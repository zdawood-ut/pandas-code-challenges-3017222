# %% [markdown]
# # Selecting a subset of columns

# %%
import pandas as pd 
import numpy as np

# %%
market = pd.read_csv('/Users/zdawood/Documents/pandas-code-challenges-3017222/data/marketing_campaign.csv', 
                     usecols=['ID','MntWines','MntFruits','MntMeatProducts','MntFishProducts','MntSweetProducts','MntGoldProds'],
                     header=0,
                     sep='\t')


market.head(10)
# Out:
#      ID  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0  5524       635         88              546              172
# 1  2174        11          1                6                2
# 2  4141       426         49              127              111
# 3  6182        11          4               20               10
# 4  5324       173         43              118               46
# 5  7446       520         42               98                0
# 6   965       235         65              164               50
# 7  6177        76         10               56                3
# 8  4855        14          0               24                3
# 9  5899        28          0                6                1
#
#    MntSweetProducts  MntGoldProds
# 0                88            88
# 1                 1             6
# 2                21            42
# 3                 3             5
# 4                27            15
# 5                42            14
# ...

# %%
market = market.set_index('ID')

# %%
market.loc[7446:2114, 'MntWines':'MntGoldProds']
# Out:
#       MntWines  MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# ID
# 7446       520         42               98                0                42
# 965        235         65              164               50                49
# 6177        76         10               56                3                 1
# 4855        14          0               24                3                 3
# 5899        28          0                6                1                 1
# 1994         5          5                6                0                 2
# 387          6         16               11               11                 1
# 2125       194         61              480              225               112
# 8180       233          2               53                3                 5
# 2569         3         14               17                6                 1
# 2114      1006         22              115               59                68
#
#       MntGoldProds
# ID
# ...
